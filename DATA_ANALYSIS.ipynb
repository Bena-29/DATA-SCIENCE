# %% [markdown]
# <a href="https://colab.research.google.com/github/Bena-29/DATA-SCIENCE/blob/main/DATA_ANALYSIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
california_housing_test=pd.read_csv('/content/sample_data/california_housing_test.csv')
california_housing_test.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
california_housing_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
california_housing_test.tail()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %%
california_housing_test.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
url='https://www.google.com/url?q=https%3A%2F%2Fdocs.google.com%2Fspreadsheets%2Fd%2Fe%2F2PACX-1vQNX3oBeyee-rQEulninLyZoBUy3JVUy3wsGkPRl-G-mbjh5iItwBfezeGkDHnwtxnLneBX3Ylm1c64%2Fpub%3Fgid%3D860339357%26single%3Dtrue%26output%3Dcsv'

# %%
df_url=pd.read_csv(url)
df_url
# Out:
#                     Item  Student                        Packaging  Price  \
# 0                brownie     Hugo  Individually Wrapped  (Plastic)   2.25
# 1                 cookie    Sally  Individually Wrapped  (Plastic)   1.25
# 2                   cake  Martina            Boxed (Clear Plastic)   9.50
# 3                cupcake      Joe                Boxed (Cardboard)   3.50
# 4                  fudge     Hugo      Individually Wrapped (Foil)   3.00
# 5           banana bread     Mark      Individually Wrapped (Foil)   2.75
# 6                  torte     Jade            Boxed (Clear Plastic)  10.50
# 7                  scone     Jade  Individually Wrapped  (Plastic)   2.00
# 8                 muffin     Anne      Individually Wrapped (Foil)   1.50
# 9   rice krispies treats  Martina  Individually Wrapped  (Plastic)   1.25
# 10             apple pie    Sally                  Box (Cardboard)  10.00
# 11          key lime pie  Martina                  Box (Cardboard)   9.50
#
# ...

# %%
df_url.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Item                   12 non-null     object
#  1   Student                12 non-null     object
#  2   Packaging              12 non-null     object
#  3   Price                  12 non-null     float64
#  4   Expense                12 non-null     float64
#  5   Quantity Sold (Day 1)  12 non-null     int64
#  6   Quantity Sold (Day 2)  12 non-null     int64
#  7   Quantity Sold (Day 3)  12 non-null     int64
#  8   Quantity Sold (Day 4)  12 non-null     int64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 996.0+ bytes

# %%
df_url.loc[2]
# Out:
# Item                                      cake
# Student                                Martina
# Packaging                Boxed (Clear Plastic)
# Price                                      9.5
# Expense                                    5.0
# Quantity Sold (Day 1)                        1
# Quantity Sold (Day 2)                        2
# Quantity Sold (Day 3)                        0
# Quantity Sold (Day 4)                        0
# Name: 2, dtype: object

# %%
df_url.reset_index('Item', inplace=True)
df_url
# Out:
#                     Item  Student                        Packaging  Price  \
# 0                brownie     Hugo  Individually Wrapped  (Plastic)   2.25
# 1                 cookie    Sally  Individually Wrapped  (Plastic)   1.25
# 2                   cake  Martina            Boxed (Clear Plastic)   9.50
# 3                cupcake      Joe                Boxed (Cardboard)   3.50
# 4                  fudge     Hugo      Individually Wrapped (Foil)   3.00
# 5           banana bread     Mark      Individually Wrapped (Foil)   2.75
# 6                  torte     Jade            Boxed (Clear Plastic)  10.50
# 7                  scone     Jade  Individually Wrapped  (Plastic)   2.00
# 8                 muffin     Anne      Individually Wrapped (Foil)   1.50
# 9   rice krispies treats  Martina  Individually Wrapped  (Plastic)   1.25
# 10             apple pie    Sally                  Box (Cardboard)  10.00
# 11          key lime pie  Martina                  Box (Cardboard)   9.50
#
# ...

# %%
df_url.loc['cake','Price']
# Out:
# np.float64(9.5)

# %%
df_url.loc[['cake']]
# Out:
#       Student              Packaging  Price  Expense  Quantity Sold (Day 1)  \
# Item
# cake  Martina  Boxed (Clear Plastic)    9.5      5.0                      1
#
#       Quantity Sold (Day 2)  Quantity Sold (Day 3)  Quantity Sold (Day 4)
# Item
# cake                      2                      0                      0

# %%
df_url.loc[['cake','brownie','cookie'],['Price','Expense']]
# Out:
#          Price  Expense
# Item
# cake      9.50     5.00
# brownie   2.25     0.25
# cookie    1.25     0.50

# %%
df_url['Item'].unique()
# Out:
# array(['brownie', 'cookie', 'cake', 'cupcake', 'fudge', 'banana bread',
#        'torte', 'scone', 'muffin', 'rice krispies treats', 'apple pie',
#        'key lime pie'], dtype=object)

# %% [markdown]
# **FILTERING**

# %%
price=df_url.loc['apple pie','Price']
price>5
# Out:
# np.True_

# %%
df_url['Price']>5
# Out:
# Item
# brownie                 False
# cookie                  False
# cake                     True
# cupcake                 False
# fudge                   False
# banana bread            False
# torte                    True
# scone                   False
# muffin                  False
# rice krispies treats    False
# apple pie                True
# key lime pie             True
# Name: Price, dtype: bool

# %%
df_url.loc[df_url['Price']>5]
# Out:
#               Student              Packaging  Price  Expense  \
# Item
# cake          Martina  Boxed (Clear Plastic)    9.5      5.0
# torte            Jade  Boxed (Clear Plastic)   10.5      5.5
# apple pie       Sally        Box (Cardboard)   10.0      4.0
# key lime pie  Martina        Box (Cardboard)    9.5      4.5
#
#               Quantity Sold (Day 1)  Quantity Sold (Day 2)  \
# Item
# cake                              1                      2
# torte                             0                      5
# apple pie                         0                      0
# key lime pie                      0                      0
#
#               Quantity Sold (Day 3)  Quantity Sold (Day 4)
# Item
# cake                              0                      0
# torte                             7                      7
# apple pie                         2                      3
# key lime pie                      3                      3

# %%
df_url[df_url['Price']>5]
# Out:
#               Student              Packaging  Price  Expense  \
# Item
# cake          Martina  Boxed (Clear Plastic)    9.5      5.0
# torte            Jade  Boxed (Clear Plastic)   10.5      5.5
# apple pie       Sally        Box (Cardboard)   10.0      4.0
# key lime pie  Martina        Box (Cardboard)    9.5      4.5
#
#               Quantity Sold (Day 1)  Quantity Sold (Day 2)  \
# Item
# cake                              1                      2
# torte                             0                      5
# apple pie                         0                      0
# key lime pie                      0                      0
#
#               Quantity Sold (Day 3)  Quantity Sold (Day 4)
# Item
# cake                              0                      0
# torte                             7                      7
# apple pie                         2                      3
# key lime pie                      3                      3

# %%
df_url[df_url['Student']=='Sally'][['Packaging','Price']]
# Out:
#                                  Packaging  Price
# Item
# cookie     Individually Wrapped  (Plastic)   1.25
# apple pie                  Box (Cardboard)  10.00

# %%
df_url[df_url['Student']=='Sally']['Item']
# Out:
# 1        cookie
# 10    apple pie
# Name: Item, dtype: object

# %% [markdown]
# **FLITERING FOR STRINGS**

# %%
df_url[df_url['Packaging'].str.contains('Individual')]['Item']
##or
df_url.loc[df_url['Packaging'].str.contains('Individual'),'Item']
# Out:
# 0                 brownie
# 1                  cookie
# 4                   fudge
# 5            banana bread
# 7                   scone
# 8                  muffin
# 9    rice krispies treats
# Name: Item, dtype: object

# %%
(df_url['Packaging']=='Individually Wrapped (Plastic)') | (df_url['Packaging']=='Individually Wrapped (Foil)')
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5      True
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# Name: Packaging, dtype: bool

# %%
df_url[(df_url['Packaging']=='Individually Wrapped (Plastic)') | (df_url['Packaging']=='Individually Wrapped (Foil)')]
# Out:
#            Item Student                    Packaging  Price  Expense  \
# 4         fudge    Hugo  Individually Wrapped (Foil)   3.00     1.00
# 5  banana bread    Mark  Individually Wrapped (Foil)   2.75     0.50
# 8        muffin    Anne  Individually Wrapped (Foil)   1.50     0.75
#
#    Quantity Sold (Day 1)  Quantity Sold (Day 2)  Quantity Sold (Day 3)  \
# 4                      0                     20                     22
# 5                      0                     10                     13
# 8                      0                      3                      4
#
#    Quantity Sold (Day 4)
# 4                     22
# 5                     13
# 8                      4

# %%
df_url['Student']=='Sally'& df_url['Price']>2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
#     361         #  (xint or xbool) and (yint or bool)
# --> 362         result = op(x, y)
#     363     except TypeError:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/roperator.py in rand_(left, right)
#      53 def rand_(left, right):
# ---> 54     return operator.and_(right, left)
#      55
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
# ...
