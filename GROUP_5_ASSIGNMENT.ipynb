# %% [markdown]
# <a href="https://colab.research.google.com/github/Bena-29/DATA-SCIENCE/blob/main/GROUP_5_ASSIGNMENT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #GROUP MEMBERS**
#
# 1.  Kemigisha Benadine......GROUP LEADER AND MODERATOR/PROVIDED THE DATASET
# 2.  Kasande Rachael.......CORRELATION MATRIX
# 3.  Ankunda Sheila........CORRELATION MATRIX
# 4.  Akandinda Evelyne......HEATMAPS
# 5.  Nabakinda Grace.......HEATMAPS(INTERPRETATION)
# 6.  Mugabe Maate Reagan.....KDE_(VISUALISATION)
# 7.  Nakhaima Josiah William....KDE(INTERPRETATION)

# %% [markdown]
# #Group 5: Heatmaps for Correlation Analysis and KDEs*
#
# 1.  Compute the correlation matrix for numerical features and visualize it using a heatmap.
# 2. Identify highly correlated variables
# 3. Use Kernel Density Estimation (KDE) plots to visualize feature distributions.
# 4. Describe the visualizations.

# %%
import pandas as pd ## we import pandas since its a core library for working with data tables and its powerful and flexible for data manipulation and analysis.

# %%
###IMPORTING PANDAS FROM GOOGLE DRIVE
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# IRIS DATASET The Iris dataset consists of 150 samples of iris flowers from three different species: Setosa, Versicolor, and Virginica. Each sample includes four features: sepal length, sepal width, petal length, and petal width.

# %%
data=pd.read_csv ("/content/drive/MyDrive/iris.csv")
data
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# data= pd.read_csv ("/content/drive/MyDrive/iris.csv")
# data

# %%
data.info()#
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# A correlation matrix is a table showing correlation coffecients between numerical variables and it is usually computed during the exploratory data analysis phase.Explotatory data analysis is the initial step done in data analysis or data science before actual data analysis is done
# The correlation values should range from -1 to 1. 1 indicates a perfect positive correlation,o indicates no correlation,-1 indicates a perfect negative correlation.

# %%
###1.Compute the correlation matrix for numerical features and visualize it using a heatmap.
correlation_matrix=data.corr(numeric_only=True)
correlation_matrix
# Out:
#               sepal.length  sepal.width  petal.length  petal.width
# sepal.length      1.000000    -0.117570      0.871754     0.817941
# sepal.width      -0.117570     1.000000     -0.428440    -0.366126
# petal.length      0.871754    -0.428440      1.000000     0.962865
# petal.width       0.817941    -0.366126      0.962865     1.000000

# %% [markdown]
# A heatmap is a type of data visualization that uses color to represent values in a matrix or table. It helps you quickly see patterns, trends, or relationships between variables.
#
# A heatmap turns numbers into colors — the higher or lower the value, the darker or brighter the color (depending on the color scheme).

# %%
##  Seaborn is a library that simplies the creation of statistically meaningfull plots with beautiful and informative default styles
## Matplotlib is a foundationaal plotting library for python,it provides a flexible way to create custom plots
## Numpy is a libray that facilates conducting of numerical mathematical calculations on ndimensional arrays
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
##Visualisation using the heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm' , fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix of Iris Numerical Features')
##Understanding the code parametres
##annot=True: Shows the actual correlation numbers inside each cell.

##cmap='coolwarm': The color scheme. Red for positive, blue for negative correlations.There othercolor schemes that can bes used as such as 'coolwarm' 'RdBu''RdYlGn'and 'Spectral'

##fmt=".2f": Format of the numbers (2 decimal places).

##linewidths=0.5: Adds space between cells to make them clearer.
# Out:
# Text(0.5, 1.0, 'Correlation Matrix of Iris Numerical Features')

# %% [markdown]
# #INTERPRETATION
#  Looking at the heatmap petal width and petal length are highly correlated with a strong positive correlation of 0.96.sepal length and petal length ar also highly correlated with a strong positive correlation of 0.87 Followed by petal widith and sepal length with a strong positice correlation of 0.82

# %% [markdown]
# **Use Kernel Density Estimation (KDE) plots to visualize feature distributions.** KDE is a non-parametric way to estimate the probability density function (PDF) of a continuous variable
# meaning it shows how your data is distributed, without assuming a specific underlying distribution (like normal or uniform).

# %%
##Kernal distribution
sns.kdeplot(data,x='sepal.length',hue='variety',fill=True)
plt.title('KDE PLOT FOR SEPAL LENGTH')
plt.show()

# %% [markdown]
# #**INTERPRETATION**
# **Setosa**
# Setosa has the shortest sepal length (around 5.0 cm) comapred to the other varieties
# **Versicolor**
# Versicolor has longer sepal length comapred to setosa.
#
# **Virginica**
# Virginica has the longest and most variable sepal length.

# %%
sns.kdeplot(data,x='sepal.width',hue='variety',fill=True)
plt.title('KDE PLOT FOR SEPAL WIDTH')
plt.show()

# %% [markdown]
# #**INTERPRETATION**
# **SETOSA**
# Setosa has longer sepal widith o approximately 5 compared to versicolor and virginica
# **VERSICOLOR**
# Has the shortest sepal widith in comparison with setosa and virginica
# **VIRGINICA**
# Has a greater sepal widith has versicolor but shorter than setosa

# %%
sns.kdeplot(data,x='petal.length',hue='variety',fill=True)
plt.title('KDE PLOT FOR PETAL LENGTH')
plt.show()

# %% [markdown]
# #**INTERPRETATION BY VARIETY**
#
# **Setosa**
# Setosa flowers have a small sepal length, in comparison with the other varieties.
#
# **Versicolor**
#
# Versicolor has relatively medium-sized sepals compared to  Setosa.
#
# **Virginica**  Virginica has the largest and most variable sepal lengths.

# %%
sns.kdeplot(data,x='petal.width',hue='variety',fill=True)
plt.title('KDE PLOT FOR PETAL WIDTH')
plt.show()

# %% [markdown]
# #**INTERPRETATION**
# Setosa has smaller petal widith  comapred to the other varieties.
# Versicolor has relatively bigger petal widith compated to setosa.
# Virginca has the largest petal widith comapared to setosa and virginica.
#
# ```
# # This is formatted as code
# ```
